# %% [markdown]
# # Area del quadrato

# %% [markdown]
# ![image.png](attachment:6415959a-592a-4573-86b2-d91869e55ef3.png)

# %%
print("Inserisci il lato di un quadrato:")
l = float(input())
while l <= 0:
    print("PIRLA!!! mi hai dato un numero negativo")
    l = float(input())
print("Adesso calcolo l'area e il perimetro")
a = l ** 2
p = l * 4
print("L'area del quadrato è: " + str(a))
print("Il perimetro del quadrato è: " + str(p))
# Out:
# Inserisci il lato di un quadrato:
#  8
# Adesso calcolo l'area e il perimetro
# L'area del quadrato è: 64.0
# Il perimetro del quadrato è: 32.0

# %% [markdown]
# # Area del quadrato o del triangolo

# %% [markdown]
# ![0b873c76-212d-4c8f-bd8a-0c8ba3531e47.jpg](attachment:9718a91c-7a21-4bc4-905e-e1e18870d175.jpg)

# %% [markdown]
# ![452da806-e2f7-41cf-8997-4a5b5f706ca6.jpg](attachment:03fd5b72-b31a-41d8-bab9-61fd428f4d7e.jpg)

# %% [markdown]
# ![063147e2-a29f-47b0-9efd-af14600916e6.jpg](attachment:08493cd7-7253-4289-8d55-f17a410c2048.jpg)

# %%
print("Premi q per l'area del quadrato o t per il triangolo")
scelta = input()
if scelta == "q":
    print("Inserisci il valore del lato")
    l = float(input())
    while l <= 0:
        print("PIRLA!!! mi hai dato un valore negativo")
        l = float(input())
    print("Ora calcolo l'area")
    a = l ** 2
else:
    if scelta == "t":
        print("Inserisci il valore della base")
        b = float(input())
        while b <= 0:
            print("PIRLA!!! mi hai dato un valore negativo")
            print("Inserisci il valore della base")
            b = float(input())
        print("Inserisci il valore del'altezza")
        h = float(input())
        while h <= 0:
            print("PIRLA!!! mi hai dato un valore negativo")
            print("Inserisci il valore del'altezza")
            h = float(input())
        print("Ora calcolo l'area")
        a = b * h / 2
    else:
        print("COGLIONE!!!")
        a = 0
print("L'area è: " + str(a))
# Out:
# Premi q per l'area del quadrato o t per il triangolo
#  q
# Inserisci il valore del lato
#  8
# Ora calcolo l'area
# L'area è: 64.0

# %% [markdown]
# # Carta, Forbice o Sasso

# %% [markdown]
# ![ae03e06d-f826-471c-978f-fcb6eae94864.jpg](attachment:36dee161-f352-4014-b7c8-9a2f58876c9d.jpg)

# %% [markdown]
# ![b8abfe94-31fa-47d6-9c9f-a1db69d65004.jpg](attachment:f01bf8c7-b925-4b40-ab06-9ce7abda5ba2.jpg)

# %% [markdown]
# ![aefdd82a-8482-4d66-b7e1-0caa832ba569.jpg](attachment:580333c3-041c-4eeb-8aeb-2e9f9de6ab65.jpg)

# %% [markdown]
# ![8a484586-f552-4856-ae8f-efce8f2a4d0e.jpg](attachment:705f6677-b53b-47a4-a551-17780a4ae7ad.jpg)

# %%
import random
random.seed()   #Prepare random number generator

print("ciao, scegli tra carta, forbice e sasso")
scelta = input()
while scelta != "carta" and scelta != "forbice" and scelta != "sasso":
    print("COGLIONE, HO DETTO CARTA, FORBICE O SASSO")
    scelta = input()
while scelta != "esci":
    numero = int(random.random() * 3)
    if numero == 0:
        computer = "carta"
    else:
        if numero == 1:
            computer = "forbice"
        else:
            computer = "sasso"
    if scelta == "carta" and computer == "sasso" or scelta == "forbice" and computer == "carta" or scelta == "sasso" and computer == "forbice":
        print(computer)
        print("hai vinto!!!")
    else:
        if scelta == "carta" and computer == "carta" or scelta == "forbice" and computer == "forbice" or scelta == "sasso" and computer == "sasso":
            print(computer)
            print("hai pareggiato!!!")
        else:
            print(computer)
            print("hai perso!!!")
    print("Scegli carta, forbice o sasso")
    scelta = input()
    while scelta != "carta" and scelta != "forbice" and scelta != "sasso" and scelta != "esci":
        print("COGLIONE, HO DETTO CARTA, FORBICE O SASSO")
        scelta = input()
# Out:
# ciao, scegli tra carta, forbice e sasso
#  sesso
# COGLIONE, HO DETTO CARTA, FORBICE O SASSO
#  sasso
# carta
# hai perso!!!
# Scegli carta, forbice o sasso
#  esci

# %% [markdown]
# # Fattoriale

# %% [markdown]
# ![de0dcc7c-eca6-487a-80c2-6e96ff8dc143.jpg](attachment:7ad1a0d8-afa2-46a4-a66d-a50d65effa37.jpg)

# %%
risultato = 1
print("Inserisi un numero per il fattoriale")
numero = int(input())
for i in range(1, numero + 1, 1):
    risultato = risultato * i
    print(risultato)
print("Il numero del fattoriale è " + str(risultato))
# Out:
# Inserisi un numero per il fattoriale
#  7
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# Il numero del fattoriale è 5040

# %% [markdown]
# # LED

# %% [markdown]
# ![0c155f74-ab63-44a6-9d17-7e8c814c9fd2.jpg](attachment:6748952d-42c0-4a47-92be-8ef4656dfc3f.jpg)

# %% [markdown]
# ![fe7d0004-25b8-46d5-94d8-1de709bf6b1a.jpg](attachment:33f79647-5444-46ba-ab85-bec7980e6d7c.jpg)

# %%
ledstate = False
print("Dimmi su che pin vuoi collegare il LED")
lED = int(input())
print("Dimmi che modalità vuoi usare per il pin collegato al LED metti true per Output e false per Input")
pinmodeLED = (input().lower == 'true')
print("Dimmi su che PIN vuoi collegare il pushbutton")
pinmodepushbutton = (input().lower == 'true')
while 1 == 1:
    print("Digita true per schiacciare il bottone per cambiare stato al LED")
    buttonstate = (input().lower == 'true')
    if ledstate == True:
        ledstate = not ledstate
    else:
        ledstate = ledstate
    print(ledstate)

# %% [markdown]
# # Lista e fattoriale

# %% [markdown]
# ![f28220eb-5f61-48c4-9d41-de4b89b57847.jpg](attachment:a8a3940d-b3be-4871-9241-9ba1318e97fd.jpg)

# %%
lista = [0] * (3)

print("Inserisci tre numeri dei quali vuoi il fattore")
for i in range(0, 2 + 1, 1):
    lista[i] = float(input())
for i in range(0, 2 + 1, 1):
    risultato = 1
    for k in range(1, lista[i]+ 1, 1):
        risultato = risultato * k
        print(risultato)

# %% [markdown]
# # Lista e uguale a 0

# %% [markdown]
# ![90d3eb17-f1cc-4de9-bb0d-406e66b3d2fc.jpg](attachment:5609e37c-78a9-4c99-be1f-c4473d17745b.jpg)

# %% [markdown]
# ![4caf9fd4-89d4-4bee-8b08-c15f0998ea61.jpg](attachment:bba7d5f7-d041-4eb4-9879-93f845f48b7b.jpg)

# %%
numeri = [0] * (3)

print("Dammi 3 numeri da controllare")
for i in range(0, 2 + 1, 1):
    numeri[i] = int(input())
for i in range(0, 2 + 1, 1):
    if numeri[i] > 0:
        print("Il numero è maggiore di 0")
    else:
        if numeri[i] < 0:
            print("Il numero è minore di 0")
        else:
            print("Il numero è 0")
    print(numeri[i])
    if fabs(numeri[i]) % 2 == 0:
        print("Il numero è pari")
    else:
        print("Il numero è dispari")

# %% [markdown]
# # Prodotto scalare

# %% [markdown]
# ![448bedb0-6bcf-4892-b2e5-054b4b1ce591.jpg](attachment:96c303dc-746f-4aa0-9a4c-d0b3ab7185c1.jpg)

# %%
lista1 = [0] * (3)
lista2 = [0] * (3)

risultato = 0
for i in range(0, 2 + 1, 1):
    for i in range(0, 2 + 1, 1):
        print("Inserisi i valori della lista 1")
        lista1[i] = float(input())
    for i in range(0, 2 + 1, 1):
        print("Inserisi i valori della lista 2")
        lista2[i] = float(input())
for i in range(0, 2 + 1, 1):
    risultato = risultato + lista1[i] * lista2[i]

# %% [markdown]
# # Richiesta lato positivo

# %% [markdown]
# ![291ef3a8-87e5-4f63-ae76-e6aaf14111d1.jpg](attachment:da7473f8-60cc-4f3e-8c14-00ba0636c4f4.jpg)

# %%
print("Inserisci il lato di un quadrato:")
l = float(input())
while l <= 0:
    print("Il numero che è stato inserito era negativo, inserire un altro numero positivo")
    l = float(input())
print("Adesso calcolo l'area e il perimetro")
a = l ** 2
p = l * 4
print("L'area del quadrato è: " + str(a))
print("Il perimetro del quadrato è: " + str(p))

# %% [markdown]
# # Striscia LED

# %% [markdown]
# ![29d16634-9831-4fb0-a99b-4e6197fe4017.jpg](attachment:64e04562-2201-423d-a382-b7f0107579d1.jpg)

# %% [markdown]
# ![7b11bf90-7823-4f2a-a7e0-b761dffa4609.jpg](attachment:7b839c9d-9741-4b05-a838-a6c7cafc023e.jpg)

# %% [markdown]
# ![1d14a23b-4267-42db-9cd9-b6d8ebc51400.jpg](attachment:cbf8f7bf-339d-4fd2-be94-c72b1bad6e00.jpg)

# %%
ledPins = [0] * (5)
ledStates = [False] * (5)
pinmode = [False] * (5)

ledcount = 5
for i in range(0, ledcount - 1 + 1, 1):
    print("Dimmi i PIN al quale attaccare i LED")
    ledPins[i] = int(input())
    ledStates[i] = False
for i in range(0, ledcount - 1 + 1, 1):
    print("Dimmi la modalità del PIN")
    pinmode[i] = (input().lower == 'true')
while 1 == 1:
    print("Dimmi il livello corrispondente del potenziometro")
    livelli = int(input())
    ledlevel = float(livelli * ledcount) / 1023
    print("Il livello è:  " + str(ledlevel))
    for thisLED in range(0, ledcount - 1 + 1, 1):
        if thisLED < ledlevel:
            ledStates[thisLED] = True
        else:
            ledStates[thisLED] = False
        print(ledStates[thisLED])

# %% [markdown]
# # Vettori

# %% [markdown]
# ![602d1b9a-86f7-4921-be61-c3e630cd9044.jpg](attachment:43393262-9d0c-4891-a4fd-0ee4c64fc467.jpg)

# %%
lista = [0] * (3)
quadrati = [0] * (3)

print("Calcolo una lista di vettori")
for i in range(0, 2 + 1, 1):
    lista[i] = float(input())
for i in range(0, 2 + 1, 1):
    quadrati[i] = lista[i] ** 2
for i in range(0, 2 + 1, 1):
    print("Il quadrato di " + str(lista[i]) + " è " + str(quadrati[i]))
